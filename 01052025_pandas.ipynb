# %%
import numpy as np
import pandas as pd

# %%
# df = pd.read_csv("placement.csv")

# %%
# df=df.copy

# %%
# p=df.sort_values(by='resume_score')
# p

# %%
# r=df.sort_index()
# r

# %%
# x=df.astype(int)     #type conversation
# df['cgpa']=df['cgpa'].astype(int)
# df

# %%
## t=df.add(4)
# t
# df['cgps']=df['cgpa'].add(4)

# %%
##t=df.add(4)
# t
# df['resume_score']=df['resume_score'].add(5)

# %%
##t=df.add(4)
# t
# df['placed']=df['placed'].add(6)

# %%
# s=df.count()
# s

# %%
# p=df.max()
# p

# %%
# q=df.min()
# q

# %%
# r=df['cgpa'].mean()
# r

# %%
# s=df['cgpa'].median()
# s

# %%
# g=df.filter(items=['cgpa','placed'])
# g

# df[['cgpa','placed']] #### second option of filtering

# %%
# s=df.filter(items=[5,6],axis=0) ## axis =0 means row wise operation
# s

# %%
# s=df.to_dict()  ## save in dictionary
# s

# %%
# q=df.to_string()  ## save in string
# q

# %%
# e=df.to_csv("path_location")

# %%
# idx=df.columns
# idx

# %%
# label=df.columns[0]  ## first column label
# label

# %%
# p=df.columns.tolist  ## list of column labels
# p

# %%
# q=df.columns.values  ## array of column labels
# q

# %%
# p=df.rename(columns={'cgps':'updated_cgpa','resume_score':'semester_marks'})    ##  how to rename a column
# p

# %%
# df['New']=dt['cgpa'].where(df['cgpa']>6, other=0)
# df.sample(8)

# %%
## df merging, concatenating

# %%
import pandas as pd

# %%
data1 = {
    "name": ["Sally", "Mary", "John"],
"age": [50, 40, 30]
}


data2 = {
    "name": ["Sally", "Peter", "Micky"],
"age": [77, 44, 22]
}

df1= pd.DataFrame (data1)
df2= pd.DataFrame(data2)
newdf= df1.merge(df2, how='right')
newdf
# Out:
#     name  age
# 0  Sally   77
# 1  Peter   44
# 2  Micky   22

# %%
# Define a dictionary containing employee data
data1 = {'Name': ['Jai', 'Princi', 'Gaurav', 'Anuj'],
         'Age': [27, 24, 22, 32],
         'Address': ['Nagpur', 'Kanpur', 'Allahabad', 'Kannuaj'],
         'Qualification': ['Msc', 'MA', 'MCA', 'Phd']}

# Define a dictionary containing employee data
data2 = {'Name': ['Abhi', 'Ayushi', 'Dhiraj', 'Hitesh'],
         'Age': [17, 14, 12, 52],
         'Address': ['Nagpur', 'Kanpur', 'Allahabad', 'Kannuaj'],
         'Qualification': ['Btech', 'B.A','B.A','B.A']}

# %%
df1= pd.DataFrame (data1)
df2= pd.DataFrame(data2)
df1
df2
# Out:
#      Name  Age    Address Qualification
# 0    Abhi   17     Nagpur         Btech
# 1  Ayushi   14     Kanpur           B.A
# 2  Dhiraj   12  Allahabad           B.A
# 3  Hitesh   52    Kannuaj           B.A

# %%
new_dt=pd.concat([df1,df2])
new_dt
# Out:
#      Name  Age    Address Qualification
# 0     Jai   27     Nagpur           Msc
# 1  Princi   24     Kanpur            MA
# 2  Gaurav   22  Allahabad           MCA
# 3    Anuj   32    Kannuaj           Phd
# 0    Abhi   17     Nagpur         Btech
# 1  Ayushi   14     Kanpur           B.A
# 2  Dhiraj   12  Allahabad           B.A
# 3  Hitesh   52    Kannuaj           B.A

# %%
df=pd.merge(df1, df2, on='Address', how='inner')
df
# Out:
#    Name_x  Age_x    Address Qualification_x  Name_y  Age_y Qualification_y
# 0     Jai     27     Nagpur             Msc    Abhi     17           Btech
# 1  Princi     24     Kanpur              MA  Ayushi     14             B.A
# 2  Gaurav     22  Allahabad             MCA  Dhiraj     12             B.A
# 3    Anuj     32    Kannuaj             Phd  Hitesh     52             B.A

# %%
# df=pd.read_csv('covid_toy.csv')
