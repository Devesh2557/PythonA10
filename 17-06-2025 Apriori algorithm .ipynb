# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('market_basket.csv', header = None)

# %%
df.head()
# Out:
#               0          1           2                 3             4   \
# 0         shrimp    almonds     avocado    vegetables mix  green grapes
# 1        burgers  meatballs        eggs               NaN           NaN
# 2        chutney        NaN         NaN               NaN           NaN
# 3         turkey    avocado         NaN               NaN           NaN
# 4  mineral water       milk  energy bar  whole wheat rice     green tea
#
#                  5     6               7             8             9   \
# 0  whole weat flour  yams  cottage cheese  energy drink  tomato juice
# 1               NaN   NaN             NaN           NaN           NaN
# 2               NaN   NaN             NaN           NaN           NaN
# 3               NaN   NaN             NaN           NaN           NaN
# 4               NaN   NaN             NaN           NaN           NaN
#
#                10         11     12     13             14      15  \
# 0  low fat yogurt  green tea  honey  salad  mineral water  salmon
# 1             NaN        NaN    NaN    NaN            NaN     NaN
# 2             NaN        NaN    NaN    NaN            NaN     NaN
# 3             NaN        NaN    NaN    NaN            NaN     NaN
# 4             NaN        NaN    NaN    NaN            NaN     NaN
#
#                   16               17       18         19
# 0  antioxydant juice  frozen smoothie  spinach  olive oil
# 1                NaN              NaN      NaN        NaN
# 2                NaN              NaN      NaN        NaN
# 3                NaN              NaN      NaN        NaN
# 4                NaN              NaN      NaN        NaN

# %%
df.shape
# Out:
# (7501, 20)

# %%
# !pip install apyori
# Out:
# Collecting apyori
#   Downloading apyori-1.1.2.tar.gz (8.6 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Building wheels for collected packages: apyori
#   Building wheel for apyori (setup.py): started
#   Building wheel for apyori (setup.py): finished with status 'done'
#   Created wheel for apyori: filename=apyori-1.1.2-py3-none-any.whl size=5974 sha256=623c7dd8b2b4bc9e3903d8981ae31a3bda1d2a31188a5e999d0d8c815a415301
#   Stored in directory: c:\users\deves\appdata\local\pip\cache\wheels\7f\49\e3\42c73b19a264de37129fadaa0c52f26cf50e87de08fb9804af
# Successfully built apyori
# Installing collected packages: apyori
# Successfully installed apyori-1.1.2

# %%
# Data Processing
transactions = []
for i in range(0,7501):
    transactions.append([str(df.values[i,j]) for j in range(0,20)])
    
#Training the dataset
from apyori import apriori
rules = apriori(transactions,
                min_support = 0.003,    #(3items 7 days in week)/(Total Rows in dataset 7501)
                min_confidence = 0.2,
                min_lift = 3,
                min_length = 2)

#Visualizing the results
a = list(rules)
result = [list(a[i][0]) for i in range(0, len(a))]

# %%
df.shape
# Out:
# (7501, 20)

# %%
result
# Out:
# [['chicken', 'light cream'],
#  ['escalope', 'mushroom cream sauce'],
#  ['escalope', 'pasta'],
#  ['honey', 'fromage blanc'],
#  ['ground beef', 'herb & pepper'],
#  ['ground beef', 'tomato sauce'],
#  ['light cream', 'olive oil'],
#  ['whole wheat pasta', 'olive oil'],
#  ['pasta', 'shrimp'],
#  ['spaghetti', 'avocado', 'milk'],
#  ['cake', 'burgers', 'milk'],
#  ['turkey', 'burgers', 'chocolate'],
#  ['turkey', 'burgers', 'milk'],
#  ['tomatoes', 'cake', 'frozen vegetables'],
#  ['ground beef', 'spaghetti', 'cereals'],
#  ['ground beef', 'chicken', 'milk'],
#  ['chicken', 'light cream', 'nan'],
#  ['chicken', 'milk', 'olive oil'],
#  ['spaghetti', 'chicken', 'olive oil'],
#  ['shrimp', 'chocolate', 'frozen vegetables'],
#  ['ground beef', 'chocolate', 'herb & pepper'],
#  ['soup', 'chocolate', 'milk'],
#  ['cooking oil', 'ground beef', 'spaghetti'],
#  ['ground beef', 'eggs', 'herb & pepper'],
#  ['red wine', 'spaghetti', 'eggs'],
#  ['escalope', 'mushroom cream sauce', 'nan'],
#  ['escalope', 'pasta', 'nan'],
#  ['ground beef', 'herb & pepper', 'french fries'],
#  ['honey', 'nan', 'fromage blanc'],
#  ['tomatoes', 'green tea', 'frozen vegetables'],
#  ['ground beef', 'spaghetti', 'frozen vegetables'],
#  ['olive oil', 'milk', 'frozen vegetables'],
#  ['soup', 'milk', 'frozen vegetables'],
#  ['tomatoes', 'milk', 'frozen vegetables'],
#  ['mineral water', 'shrimp', 'frozen vegetables'],
#  ['olive oil', 'spaghetti', 'frozen vegetables'],
#  ['spaghetti', 'shrimp', 'frozen vegetables'],
#  ['tomatoes', 'shrimp', 'frozen vegetables'],
#  ['tomatoes', 'spaghetti', 'frozen vegetables'],
#  ['ground beef', 'spaghetti', 'grated cheese'],
#  ['tomatoes', 'ground beef', 'green tea'],
#  ['ground beef', 'milk', 'herb & pepper'],
#  ['ground beef', 'mineral water', 'herb & pepper'],
#  ['ground beef', 'nan', 'herb & pepper'],
#  ['ground beef', 'spaghetti', 'herb & pepper'],
#  ['ground beef', 'milk', 'olive oil'],
#  ['ground beef', 'milk', 'soup'],
#  ['ground beef', 'tomato sauce', 'nan'],
#  ['ground beef', 'spaghetti', 'pepper'],
#  ['ground beef', 'spaghetti', 'shrimp'],
#  ['ground beef', 'spaghetti', 'tomato sauce'],
#  ['spaghetti', 'mineral water', 'light cream'],
#  ['olive oil', 'light cream', 'nan'],
#  ['shrimp', 'milk', 'olive oil'],
#  ['soup', 'milk', 'olive oil'],
#  ['spaghetti', 'milk', 'olive oil'],
#  ['tomatoes', 'milk', 'soup'],
#  ['spaghetti', 'milk', 'whole wheat pasta'],
#  ['mineral water', 'soup', 'olive oil'],
#  ['whole wheat pasta', 'mineral water', 'olive oil'],
#  ['whole wheat pasta', 'nan', 'olive oil'],
#  ['pasta', 'shrimp', 'nan'],
#  ['pancakes', 'spaghetti', 'olive oil'],
#  ['tomatoes', 'spaghetti', 'olive oil'],
#  ['tomatoes', 'whole wheat rice', 'spaghetti'],
#  ['spaghetti', 'avocado', 'milk', 'nan'],
#  ['cake', 'burgers', 'milk', 'nan'],
#  ['turkey', 'burgers', 'chocolate', 'nan'],
#  ['turkey', 'burgers', 'milk', 'nan'],
#  ['tomatoes', 'cake', 'nan', 'frozen vegetables'],
#  ['ground beef', 'spaghetti', 'cereals', 'nan'],
#  ['ground beef', 'chicken', 'milk', 'nan'],
#  ['olive oil', 'chicken', 'milk', 'nan'],
#  ['spaghetti', 'chicken', 'nan', 'olive oil'],
#  ['ground beef', 'mineral water', 'eggs', 'chocolate'],
#  ['ground beef', 'mineral water', 'chocolate', 'frozen vegetables'],
#  ['ground beef', 'spaghetti', 'chocolate', 'frozen vegetables'],
#  ['milk', 'mineral water', 'chocolate', 'frozen vegetables'],
#  ['milk', 'spaghetti', 'chocolate', 'frozen vegetables'],
#  ['mineral water', 'shrimp', 'chocolate', 'frozen vegetables'],
#  ['shrimp', 'nan', 'chocolate', 'frozen vegetables'],
#  ['ground beef', 'nan', 'chocolate', 'herb & pepper'],
#  ['soup', 'nan', 'chocolate', 'milk'],
#  ['spaghetti', 'mineral water', 'chocolate', 'olive oil'],
#  ['spaghetti', 'mineral water', 'shrimp', 'chocolate'],
#  ['cooking oil', 'ground beef', 'spaghetti', 'nan'],
#  ['milk', 'mineral water', 'eggs', 'frozen vegetables'],
#  ['ground beef', 'nan', 'eggs', 'herb & pepper'],
#  ['red wine', 'spaghetti', 'eggs', 'nan'],
#  ['ground beef', 'herb & pepper', 'nan', 'french fries'],
#  ['spaghetti', 'mineral water', 'frozen smoothie', 'milk'],
#  ['tomatoes', 'green tea', 'nan', 'frozen vegetables'],
#  ['ground beef', 'mineral water', 'milk', 'frozen vegetables'],
#  ['ground beef', 'spaghetti', 'milk', 'frozen vegetables'],
#  ['spaghetti', 'ground beef', 'mineral water', 'frozen vegetables'],
#  ['ground beef', 'spaghetti', 'nan', 'frozen vegetables'],
#  ['olive oil', 'mineral water', 'milk', 'frozen vegetables'],
#  ['mineral water', 'soup', 'milk', 'frozen vegetables'],
#  ['spaghetti', 'mineral water', 'milk', 'frozen vegetables'],
#  ['olive oil', 'nan', 'milk', 'frozen vegetables'],
#  ['soup', 'nan', 'milk', 'frozen vegetables'],
#  ['tomatoes', 'nan', 'milk', 'frozen vegetables'],
#  ['mineral water', 'shrimp', 'nan', 'frozen vegetables'],
#  ['spaghetti', 'mineral water', 'shrimp', 'frozen vegetables'],
#  ['tomatoes', 'spaghetti', 'mineral water', 'frozen vegetables'],
#  ['olive oil', 'spaghetti', 'nan', 'frozen vegetables'],
#  ['spaghetti', 'shrimp', 'nan', 'frozen vegetables'],
#  ['tomatoes', 'shrimp', 'nan', 'frozen vegetables'],
#  ['tomatoes', 'spaghetti', 'nan', 'frozen vegetables'],
#  ['ground beef', 'spaghetti', 'nan', 'grated cheese'],
#  ['tomatoes', 'ground beef', 'green tea', 'nan'],
#  ['ground beef', 'nan', 'milk', 'herb & pepper'],
#  ['ground beef', 'mineral water', 'nan', 'herb & pepper'],
#  ['ground beef', 'spaghetti', 'nan', 'herb & pepper'],
#  ['spaghetti', 'ground beef', 'mineral water', 'milk'],
#  ['olive oil', 'ground beef', 'milk', 'nan'],
#  ['ground beef', 'soup', 'milk', 'nan'],
#  ['spaghetti', 'ground beef', 'mineral water', 'olive oil'],
#  ['pancakes', 'spaghetti', 'ground beef', 'mineral water'],
#  ['tomatoes', 'spaghetti', 'ground beef', 'mineral water'],
#  ['ground beef', 'spaghetti', 'pepper', 'nan'],
#  ['ground beef', 'spaghetti', 'shrimp', 'nan'],
#  ['ground beef', 'spaghetti', 'tomato sauce', 'nan'],
#  ['spaghetti', 'mineral water', 'light cream', 'nan'],
#  ['spaghetti', 'mineral water', 'milk', 'olive oil'],
#  ['tomatoes', 'spaghetti', 'mineral water', 'milk'],
#  ['olive oil', 'shrimp', 'milk', 'nan'],
#  ['olive oil', 'soup', 'milk', 'nan'],
#  ['olive oil', 'spaghetti', 'milk', 'nan'],
#  ['tomatoes', 'soup', 'milk', 'nan'],
#  ['whole wheat pasta', 'spaghetti', 'milk', 'nan'],
#  ['mineral water', 'soup', 'nan', 'olive oil'],
#  ['whole wheat pasta', 'mineral water', 'nan', 'olive oil'],
#  ['pancakes', 'spaghetti', 'nan', 'olive oil'],
#  ['tomatoes', 'spaghetti', 'nan', 'olive oil'],
#  ['tomatoes', 'whole wheat rice', 'spaghetti', 'nan'],
#  ['ground beef', 'eggs', 'chocolate', 'nan', 'mineral water'],
#  ['ground beef', 'chocolate', 'nan', 'mineral water', 'frozen vegetables'],
#  ['ground beef', 'chocolate', 'spaghetti', 'nan', 'frozen vegetables'],
#  ['milk', 'chocolate', 'nan', 'mineral water', 'frozen vegetables'],
#  ['milk', 'chocolate', 'spaghetti', 'nan', 'frozen vegetables'],
#  ['shrimp', 'chocolate', 'nan', 'mineral water', 'frozen vegetables'],
#  ['chocolate', 'spaghetti', 'nan', 'olive oil', 'mineral water'],
#  ['shrimp', 'chocolate', 'spaghetti', 'nan', 'mineral water'],
#  ['milk', 'eggs', 'nan', 'mineral water', 'frozen vegetables'],
#  ['milk', 'spaghetti', 'frozen smoothie', 'nan', 'mineral water'],
#  ['ground beef', 'milk', 'nan', 'mineral water', 'frozen vegetables'],
#  ['ground beef', 'milk', 'spaghetti', 'nan', 'frozen vegetables'],
#  ['ground beef', 'spaghetti', 'nan', 'mineral water', 'frozen vegetables'],
#  ['milk', 'nan', 'olive oil', 'mineral water', 'frozen vegetables'],
#  ['soup', 'milk', 'nan', 'mineral water', 'frozen vegetables'],
#  ['milk', 'spaghetti', 'nan', 'mineral water', 'frozen vegetables'],
#  ['shrimp', 'spaghetti', 'nan', 'mineral water', 'frozen vegetables'],
#  ['tomatoes', 'spaghetti', 'nan', 'mineral water', 'frozen vegetables'],
#  ['ground beef', 'milk', 'spaghetti', 'nan', 'mineral water'],
#  ['ground beef', 'spaghetti', 'nan', 'olive oil', 'mineral water'],
#  ['ground beef', 'spaghetti', 'nan', 'pancakes', 'mineral water'],
#  ['ground beef', 'tomatoes', 'spaghetti', 'nan', 'mineral water'],
#  ['milk', 'spaghetti', 'nan', 'olive oil', 'mineral water'],
#  ['tomatoes', 'milk', 'spaghetti', 'nan', 'mineral water']]
