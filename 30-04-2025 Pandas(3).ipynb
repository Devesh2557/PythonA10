# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("C:\\Users\\deves\\Desktop\\pandas\\placement.csv")

# %%
df.head()
# Out:
#    cgpa  resume_score  placed
# 0  8.14          6.52       1
# 1  6.17          5.17       0
# 2  8.27          8.86       1
# 3  6.88          7.27       1
# 4  7.52          7.30       1

# %%
df.tail()
# Out:
#     cgpa  resume_score  placed
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0

# %%
df.describe()    #it is use to view the data statically.(means it shows the max min values) mahtmatically representation of data
# Out:
#            cgpa  resume_score      placed
# count  100.0000    100.000000  100.000000
# mean     6.9422      6.930500    0.500000
# std      1.1192      0.979608    0.502519
# min      5.2700      4.950000    0.000000
# 25%      5.9800      6.190000    0.000000
# 50%      6.6200      7.055000    0.500000
# 75%      8.0450      7.640000    1.000000
# max      9.4000      9.060000    1.000000

# %%
df.info()     # Data type information
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   cgpa          100 non-null    float64
#  1   resume_score  100 non-null    float64
#  2   placed        100 non-null    int64
# dtypes: float64(2), int64(1)
# memory usage: 2.5 KB

# %%
top_left_corner_df=df.iloc[:4,:3]  # # iloc[row_range,column_name]
top_left_corner_df
# Out:
#    cgpa  resume_score  placed
# 0  8.14          6.52       1
# 1  6.17          5.17       0
# 2  8.27          8.86       1
# 3  6.88          7.27       1

# %%
df.loc[1:3,['cgpa','placed']]     # loc[row_range,column_names]
# Out:
#    cgpa  placed
# 1  6.17       0
# 2  8.27       1
# 3  6.88       1

# %%
p=df.dtypes                       ## dtypes is check the data types of columns
p
# Out:
# cgpa            float64
# resume_score    float64
# placed            int64
# dtype: object

# %%
b=df.empty      ## It returns true if there is any missing values others it returns false 
b
# Out:
# False

# %%
df.isnull().sum()     ## It is use for checking missing values
# Out:
# cgpa            0
# resume_score    0
# placed          0
# dtype: int64

# %%
df=df.dropna()        ## It is use for remove missing rows.

# %%
df=pd.read_csv("C:\\Users\\deves\\Desktop\\pandas\\flipkart.csv")

# %%
df
# Out:
#                                            Mobiles  Ratings           Reviews  \
# 0           Nothing Phone (3a) Pro (Black, 256 GB)      4.5     2,981 Ratings
# 1                  Apple iPhone 16 (White, 128 GB)      4.6    10,996 Ratings
# 2                  Apple iPhone 16 (Black, 128 GB)      4.6    10,996 Ratings
# 3            Apple iPhone 16 (Ultramarine, 128 GB)      4.6    10,996 Ratings
# 4       SAMSUNG Galaxy S24 5G (Onyx Black, 128 GB)      4.5     1,998 Ratings
# 5     SAMSUNG Galaxy S24 5G (Amber Yellow, 256 GB)      4.5     1,998 Ratings
# 6   SAMSUNG Galaxy S24+ 5G (Cobalt Violet, 256 GB)      4.5     7,978 Ratings
# 7                   Apple iPhone 16 (Teal, 256 GB)      4.6    10,996 Ratings
# 8                   Apple iPhone 16 (Pink, 128 GB)      4.6    10,996 Ratings
# 9      SAMSUNG Galaxy S24+ 5G (Onyx Black, 256 GB)      4.5     7,978 Ratings
# 10           vivo V40 Pro 5G (Ganges Blue, 512 GB)      4.5       855 Ratings
# ...

# %%
df.head()
# Out:
#                                       Mobiles  Ratings         Reviews  \
# 0      Nothing Phone (3a) Pro (Black, 256 GB)      4.5   2,981 Ratings
# 1             Apple iPhone 16 (White, 128 GB)      4.6  10,996 Ratings
# 2             Apple iPhone 16 (Black, 128 GB)      4.6  10,996 Ratings
# 3       Apple iPhone 16 (Ultramarine, 128 GB)      4.6  10,996 Ratings
# 4  SAMSUNG Galaxy S24 5G (Onyx Black, 128 GB)      4.5   1,998 Ratings
#
#       Reviews2                Storage  \
# 0  345 Reviews  8 GB RAM | 256 GB ROM
# 1  531 Reviews             128 GB ROM
# 2  531 Reviews             128 GB ROM
# 3  531 Reviews             128 GB ROM
# 4  180 Reviews  8 GB RAM | 128 GB ROM
#
#                                         Display  \
# 0          17.2 cm (6.77 inch) Full HD+ Display
# 1  15.49 cm (6.1 inch) Super Retina XDR Display
# 2  15.49 cm (6.1 inch) Super Retina XDR Display
# 3  15.49 cm (6.1 inch) Super Retina XDR Display
# 4          15.75 cm (6.2 inch) Full HD+ Display
#
# ...

# %%
df.tail()
# Out:
#                                         Mobiles  Ratings           Reviews  \
# 19         Apple iPhone 16 Plus (Black, 256 GB)      4.6     1,994 Ratings
# 20  SAMSUNG Galaxy S24 5G (Marble Gray, 256 GB)      4.5     1,998 Ratings
# 21          Apple iPhone 14 (Starlight, 256 GB)      4.6  3,11,310 Ratings
# 22        OPPO Find X8 5G (Space Black, 512 GB)      4.5        63 Ratings
# 23          OPPO Find X8 5G (Star Grey, 256 GB)      4.6       610 Ratings
#
#           Reviews2                 Storage  \
# 19     117 Reviews              256 GB ROM
# 20     180 Reviews   8 GB RAM | 256 GB ROM
# 21  11,676 Reviews              256 GB ROM
# 22      15 Reviews  16 GB RAM | 512 GB ROM
# 23     142 Reviews  12 GB RAM | 256 GB ROM
#
#                                          Display  \
# 19  17.02 cm (6.7 inch) Super Retina XDR Display
# 20          15.75 cm (6.2 inch) Full HD+ Display
# 21  15.49 cm (6.1 inch) Super Retina XDR Display
# 22  16.74 cm (6.59 inch) Full HD+ AMOLED Display
# ...

# %%
df.sample()
# Out:
#                                         Mobiles  Ratings        Reviews  \
# 5  SAMSUNG Galaxy S24 5G (Amber Yellow, 256 GB)      4.5  1,998 Ratings
#
#       Reviews2                Storage                               Display  \
# 5  180 Reviews  8 GB RAM | 256 GB ROM  15.75 cm (6.2 inch) Full HD+ Display
#
#                                    Camera           Battery  \
# 5  50MP + 10MP + 12MP | 12MP Front Camera  4000 mAh Battery
#
#                Insurance                                           Warrenty  \
# 5  Exynos 2400 Processor  1 Year Manufacturer Warranty for Device and 6 ...
#
#   Discounted_price Actual_Price         Exchange
# 5          ₹50,999      ₹79,999  Off on Exchange
