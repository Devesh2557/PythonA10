# %%
# LogisticRegressionModel------------> Supervised ML Model-------------> Classify

# When we have target column as categorical data.

# LogisticRegressionModel--- -------> Into this there a function works in backend which is known as Sigmoid Activation Function.
# Sigmoid Activation Function--------> (They are like mathematical function which converts data into scaled function so that ore neural networks works 
# continue in a flow.) It works when we have target column as categorical data and we have only 2 sub-categories.

# sub-categorey converts it into probability and that have 0-1

# if x>=0.5:
#     return 1
# else:
#     return 0

# Performance Evaluation Metrics --------> Accuracy_score, precision, recall

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('Social_Network_Ads.csv')

# %%
df.head()
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510    Male   19            19000          0
# 1  15810944    Male   35            20000          0
# 2  15668575  Female   26            43000          0
# 3  15603246  Female   27            57000          0
# 4  15804002    Male   19            76000          0

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lb = LabelEncoder()

# %%
df['Gender']= lb.fit_transform(df['Gender'])

# %%
df.head()
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510       1   19            19000          0
# 1  15810944       1   35            20000          0
# 2  15668575       0   26            43000          0
# 3  15603246       0   27            57000          0
# 4  15804002       1   19            76000          0

# %%
df = df.drop(columns=['User ID'])

# %%
df.head()
# Out:
#    Gender  Age  EstimatedSalary  Purchased
# 0       1   19            19000          0
# 1       1   35            20000          0
# 2       0   26            43000          0
# 3       0   27            57000          0
# 4       1   19            76000          0

# %%
x = df.drop(columns = ['Purchased'])
y = df['Purchased']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size = 0.2, random_state=42)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression()

# %%
lr.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = lr.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.8875

# %%
from sklearn.metrics import precision_score

# %%
precision_score(y_test, y_pred)  ##### True positive rate
# Out:
# 0.9130434782608695

# %%
from sklearn.metrics import confusion_matrix

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[50,  2],
#        [ 7, 21]], dtype=int64)

# %%
# 50-------> true positive
# 21--------> true negative
# 2---------> false positive
# 7---------> false negative
